# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install --quiet vietocr
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.9/133.9 kB 8.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.2/299.2 kB 11.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.9/14.9 MB 60.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 101.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 25.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.5/313.5 kB 38.6 MB/s eta 0:00:00
#   Building wheel for gdown (pyproject.toml) ... done
#   Building wheel for prefetch-generator (setup.py) ... done

# %%
config = {'vocab': 'aAàÀảẢãÃáÁạẠăĂằẰẳẲẵẴắẮặẶâÂầẦẩẨẫẪấẤậẬbBcCdDđĐeEèÈẻẺẽẼéÉẹẸêÊềỀểỂễỄếẾệỆfFgGhHiIìÌỉỈĩĨíÍịỊjJkKlLmMnNoOòÒỏỎõÕóÓọỌôÔồỒổỔỗỖốỐộỘơƠờỜởỞỡỠớỚợỢpPqQrRsStTuUùÙủỦũŨúÚụỤưƯừỪửỬữỮứỨựỰvVwWxXyYỳỲỷỶỹỸýÝỵỴzZ0123456789!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ ',
 'device': 'cuda:0',
 'seq_modeling': 'transformer',
 'transformer': {'d_model': 256,
  'nhead': 8,
  'num_encoder_layers': 6,
  'num_decoder_layers': 6,
  'dim_feedforward': 2048,
  'max_seq_length': 1024,
  'pos_dropout': 0.1,
  'trans_dropout': 0.1},
 'optimizer': {'max_lr': 0.0003, 'pct_start': 0.1},
 'trainer': {'batch_size': 32,
  'print_every': 200,
  'valid_every': 3000,
  'iters': 20000,
  'export': './weights/transformerocr.pth',
  'checkpoint': './checkpoint/transformerocr_checkpoint.pth',
  'log': './train.log',
  'metrics': 10000},
 'dataset': {'name': 'hw',
  'data_root': './data_line/',
  'train_annotation': 'train_line_annotation.txt',
  'valid_annotation': 'test_line_annotation.txt',
  'image_height': 32,
  'image_min_width': 32,
  'image_max_width': 512},
 'dataloader': {'num_workers': 3, 'pin_memory': True},
 'aug': {'image_aug': True, 'masked_language_model': True},
 'predictor': {'beamsearch': False},
 'quiet': False,
 'pretrain': '/content/drive/MyDrive/OCR/Weights/transformer/vgg_transformer.pth',
 'weights': '/content/drive/MyDrive/OCR/Weights/transformer/vgg_transformer.pth',
 'backbone': 'vgg19_bn',
 'cnn': {'pretrained': True,
  'ss': [[2, 2], [2, 2], [2, 1], [2, 1], [1, 1]],
  'ks': [[2, 2], [2, 2], [2, 1], [2, 1], [1, 1]],
  'hidden': 256}}

# %%
from vietocr.tool.config import Cfg
from vietocr.model.trainer import Trainer

# config = Cfg.load_config_from_name('vgg_transformer')

# Các bạn có thể thay đổi tập vocab của mình hoặc để mặc định vì tập vocab của mình đã tương đối đầy từ các kí tự rồi
# lưu ý rằng các kí tự không có trong tập vocab sẽ bị lỗi
#config['vocab'] = 'tập vocab'

dataset_params = {
    'name':'customeOcr',
    'data_root':'/content/drive/MyDrive/OCR/Dataset/gendata',
    'train_annotation':'train_annotation.txt', # ảnh và nhãn tập train
    'valid_annotation':'valid_annotation.txt' # ảnh và nhãn tập test
}

params = {
         'print_every':200, # hiển thị loss mỗi 200 iteration
         'valid_every':10000, # đánh giá độ chính xác mô hình mỗi 10000 iteraction
          'iters':20000, # Huấn luyện 20000 lần
          'export':'/content/drive/MyDrive/OCR/Weights/ocr/transformerocr.pth', # lưu model được huấn luyện tại này
          'metrics': 10000 # sử dụng 10000 ảnh của tập test để đánh giá mô hình
         }

# update custom config của các bạn
config['trainer'].update(params)
config['dataset'].update(dataset_params)
config['device'] = 'cuda:0' # device để huấn luyện mô hình, để sử dụng cpu huấn luyện thì thay bằng 'cpu'

# huấn luyện mô hình từ pretrained model của mình sẽ nhanh hội tụ và cho kết quả tốt hơn khi bạn chỉ có bộ dataset nhỏ
# để sử dụng custom augmentation, các bạn có thể sử dụng Trainer(config, pretrained=True, augmentor=MyAugmentor()) theo ví dụ trên.
trainer = Trainer(config, pretrained=True)

# sử dụng lệnh này để visualize tập train, bao gồm cả augmentation
trainer.visualize_dataset()

# bắt đầu huấn luyện
trainer.train()

# visualize kết quả dự đoán của mô hình
trainer.visualize_prediction()

# huấn luyện xong thì lưu lại config để dùng cho Predictor
trainer.config.save('config.yml')
# Out:
# Downloading: "https://download.pytorch.org/models/vgg19_bn-c79401a0.pth" to /root/.cache/torch/hub/checkpoints/vgg19_bn-c79401a0.pth
# 100%|██████████| 548M/548M [00:04<00:00, 122MB/s]
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# Create train_customeOcr: 100%|██████████████████████████████████| 3900/3900 [04:36<00:00, 14.11it/s]
# Remove 2700 invalid images
# Created dataset with 1199 samples
# train_customeOcr build cluster: 100%|████████████████████████| 1199/1199 [00:00<00:00, 74692.49it/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Create valid_customeOcr: 100%|██████████████████████████████████| 1800/1800 [06:46<00:00,  4.43it/s]
# Created dataset with 1799 samples
# valid_customeOcr build cluster: 100%|████████████████████████| 1799/1799 [00:00<00:00, 77216.06it/s]
# iter: 000200 - train loss: 2.006 - lr: 1.91e-05 - load time: 1.77 - gpu time: 26.12
# iter: 000400 - train loss: 1.679 - lr: 3.95e-05 - load time: 1.81 - gpu time: 23.40
# iter: 000600 - train loss: 1.583 - lr: 7.14e-05 - load time: 2.51 - gpu time: 24.77
# iter: 000800 - train loss: 1.552 - lr: 1.12e-04 - load time: 1.72 - gpu time: 23.96
# iter: 001000 - train loss: 1.527 - lr: 1.56e-04 - load time: 1.93 - gpu time: 23.37
# iter: 001200 - train loss: 1.528 - lr: 2.01e-04 - load time: 1.90 - gpu time: 23.90
# iter: 001400 - train loss: 1.492 - lr: 2.41e-04 - load time: 1.50 - gpu time: 24.01
# iter: 001600 - train loss: 1.486 - lr: 2.73e-04 - load time: 1.91 - gpu time: 24.35
# iter: 001800 - train loss: 1.446 - lr: 2.93e-04 - load time: 2.10 - gpu time: 24.50
# iter: 002000 - train loss: 1.407 - lr: 3.00e-04 - load time: 1.92 - gpu time: 23.91
# iter: 002200 - train loss: 1.324 - lr: 3.00e-04 - load time: 1.61 - gpu time: 24.13
# iter: 002400 - train loss: 1.262 - lr: 3.00e-04 - load time: 1.79 - gpu time: 23.62
# iter: 002600 - train loss: 1.216 - lr: 2.99e-04 - load time: 1.89 - gpu time: 23.76
# iter: 002800 - train loss: 1.169 - lr: 2.99e-04 - load time: 1.64 - gpu time: 24.51
# iter: 003000 - train loss: 1.121 - lr: 2.98e-04 - load time: 1.88 - gpu time: 24.99
# iter: 003200 - train loss: 1.099 - lr: 2.97e-04 - load time: 1.80 - gpu time: 23.70
# iter: 003400 - train loss: 1.060 - lr: 2.96e-04 - load time: 2.10 - gpu time: 24.62
# iter: 003600 - train loss: 1.048 - lr: 2.94e-04 - load time: 1.68 - gpu time: 23.97
# iter: 003800 - train loss: 1.023 - lr: 2.93e-04 - load time: 1.80 - gpu time: 23.59
# iter: 004000 - train loss: 1.005 - lr: 2.91e-04 - load time: 1.93 - gpu time: 23.45
# iter: 004200 - train loss: 0.994 - lr: 2.89e-04 - load time: 1.97 - gpu time: 25.33
# iter: 004400 - train loss: 0.976 - lr: 2.87e-04 - load time: 2.00 - gpu time: 23.69
# iter: 004600 - train loss: 0.971 - lr: 2.85e-04 - load time: 1.83 - gpu time: 23.91
# iter: 004800 - train loss: 0.961 - lr: 2.82e-04 - load time: 1.67 - gpu time: 23.63
# iter: 005000 - train loss: 0.954 - lr: 2.80e-04 - load time: 1.96 - gpu time: 24.37
# iter: 005200 - train loss: 0.948 - lr: 2.77e-04 - load time: 1.94 - gpu time: 24.00
# iter: 005400 - train loss: 0.942 - lr: 2.74e-04 - load time: 1.91 - gpu time: 24.54
# iter: 005600 - train loss: 0.936 - lr: 2.71e-04 - load time: 1.66 - gpu time: 23.65
# iter: 005800 - train loss: 0.930 - lr: 2.68e-04 - load time: 2.00 - gpu time: 24.53
# iter: 006000 - train loss: 0.932 - lr: 2.65e-04 - load time: 1.96 - gpu time: 23.98
# iter: 006200 - train loss: 0.922 - lr: 2.61e-04 - load time: 1.66 - gpu time: 23.71
# iter: 006400 - train loss: 0.918 - lr: 2.58e-04 - load time: 1.74 - gpu time: 24.15
# iter: 006600 - train loss: 0.914 - lr: 2.54e-04 - load time: 2.33 - gpu time: 25.34
# iter: 006800 - train loss: 0.909 - lr: 2.50e-04 - load time: 1.86 - gpu time: 23.62
# iter: 007000 - train loss: 0.908 - lr: 2.46e-04 - load time: 1.65 - gpu time: 23.73
# iter: 007200 - train loss: 0.904 - lr: 2.42e-04 - load time: 1.86 - gpu time: 24.60
# iter: 007400 - train loss: 0.901 - lr: 2.38e-04 - load time: 1.81 - gpu time: 23.79
# iter: 007600 - train loss: 0.901 - lr: 2.34e-04 - load time: 1.67 - gpu time: 23.70
# iter: 007800 - train loss: 0.895 - lr: 2.29e-04 - load time: 2.22 - gpu time: 24.61
# iter: 008000 - train loss: 0.891 - lr: 2.25e-04 - load time: 1.74 - gpu time: 23.95
# iter: 008200 - train loss: 0.889 - lr: 2.20e-04 - load time: 2.00 - gpu time: 24.55
# iter: 008400 - train loss: 0.887 - lr: 2.16e-04 - load time: 1.52 - gpu time: 23.47
# iter: 008600 - train loss: 0.882 - lr: 2.11e-04 - load time: 1.84 - gpu time: 23.85
# iter: 008800 - train loss: 0.880 - lr: 2.06e-04 - load time: 2.02 - gpu time: 23.70
# iter: 009000 - train loss: 0.883 - lr: 2.01e-04 - load time: 1.92 - gpu time: 23.57
# iter: 009200 - train loss: 0.878 - lr: 1.96e-04 - load time: 2.09 - gpu time: 24.45
# iter: 009400 - train loss: 0.876 - lr: 1.91e-04 - load time: 1.90 - gpu time: 23.42
# iter: 009600 - train loss: 0.876 - lr: 1.86e-04 - load time: 1.74 - gpu time: 24.13
# iter: 009800 - train loss: 0.871 - lr: 1.81e-04 - load time: 1.71 - gpu time: 23.71
# iter: 010000 - train loss: 0.867 - lr: 1.76e-04 - load time: 2.05 - gpu time: 24.27
# iter: 010000 - valid loss: 3.199 - acc full seq: 0.2901 - acc per char: 0.3441
# iter: 010200 - train loss: 0.867 - lr: 1.71e-04 - load time: 2.40 - gpu time: 25.47
# iter: 010400 - train loss: 0.865 - lr: 1.66e-04 - load time: 1.86 - gpu time: 23.35
# iter: 010600 - train loss: 0.865 - lr: 1.60e-04 - load time: 1.86 - gpu time: 24.18
# iter: 010800 - train loss: 0.864 - lr: 1.55e-04 - load time: 2.14 - gpu time: 24.05
# iter: 011000 - train loss: 0.863 - lr: 1.50e-04 - load time: 1.95 - gpu time: 23.24
# iter: 011200 - train loss: 0.860 - lr: 1.45e-04 - load time: 1.73 - gpu time: 23.48
# iter: 011400 - train loss: 0.861 - lr: 1.40e-04 - load time: 2.71 - gpu time: 25.09
# iter: 011600 - train loss: 0.856 - lr: 1.34e-04 - load time: 2.04 - gpu time: 24.02
# iter: 011800 - train loss: 0.858 - lr: 1.29e-04 - load time: 1.89 - gpu time: 23.57
# iter: 012000 - train loss: 0.855 - lr: 1.24e-04 - load time: 1.82 - gpu time: 23.82
# iter: 012200 - train loss: 0.855 - lr: 1.19e-04 - load time: 2.07 - gpu time: 24.50
# iter: 012400 - train loss: 0.852 - lr: 1.14e-04 - load time: 2.09 - gpu time: 23.77
# iter: 012600 - train loss: 0.853 - lr: 1.09e-04 - load time: 1.53 - gpu time: 23.29
# iter: 012800 - train loss: 0.850 - lr: 1.04e-04 - load time: 2.35 - gpu time: 25.24
# iter: 013000 - train loss: 0.850 - lr: 9.87e-05 - load time: 2.15 - gpu time: 23.37
# iter: 013200 - train loss: 0.849 - lr: 9.38e-05 - load time: 2.27 - gpu time: 24.37
# iter: 013400 - train loss: 0.850 - lr: 8.90e-05 - load time: 1.80 - gpu time: 23.81
# iter: 013600 - train loss: 0.848 - lr: 8.42e-05 - load time: 2.04 - gpu time: 23.89
# iter: 013800 - train loss: 0.848 - lr: 7.96e-05 - load time: 2.21 - gpu time: 24.02
# iter: 014000 - train loss: 0.846 - lr: 7.50e-05 - load time: 2.33 - gpu time: 25.25
# iter: 014200 - train loss: 0.846 - lr: 7.05e-05 - load time: 2.11 - gpu time: 24.39
# iter: 014400 - train loss: 0.845 - lr: 6.61e-05 - load time: 1.98 - gpu time: 23.66
# iter: 014600 - train loss: 0.844 - lr: 6.18e-05 - load time: 2.08 - gpu time: 23.58
# iter: 014800 - train loss: 0.843 - lr: 5.76e-05 - load time: 1.93 - gpu time: 24.71
# iter: 015000 - train loss: 0.842 - lr: 5.36e-05 - load time: 2.07 - gpu time: 23.85
# iter: 015200 - train loss: 0.843 - lr: 4.96e-05 - load time: 2.21 - gpu time: 24.22
# iter: 015400 - train loss: 0.842 - lr: 4.58e-05 - load time: 1.55 - gpu time: 23.27
# iter: 015600 - train loss: 0.841 - lr: 4.21e-05 - load time: 2.08 - gpu time: 23.73
# iter: 015800 - train loss: 0.839 - lr: 3.85e-05 - load time: 2.06 - gpu time: 24.14
# iter: 016000 - train loss: 0.841 - lr: 3.51e-05 - load time: 2.02 - gpu time: 24.19
# iter: 016200 - train loss: 0.841 - lr: 3.18e-05 - load time: 1.76 - gpu time: 23.93
# iter: 016400 - train loss: 0.842 - lr: 2.86e-05 - load time: 2.08 - gpu time: 23.48
# iter: 016600 - train loss: 0.841 - lr: 2.56e-05 - load time: 2.13 - gpu time: 25.05
# iter: 016800 - train loss: 0.839 - lr: 2.28e-05 - load time: 1.73 - gpu time: 23.64
# iter: 017000 - train loss: 0.838 - lr: 2.01e-05 - load time: 2.14 - gpu time: 24.18
# iter: 017200 - train loss: 0.839 - lr: 1.75e-05 - load time: 1.98 - gpu time: 22.92
# iter: 017400 - train loss: 0.839 - lr: 1.52e-05 - load time: 2.19 - gpu time: 24.58
# iter: 017600 - train loss: 0.839 - lr: 1.30e-05 - load time: 1.88 - gpu time: 23.70
# iter: 017800 - train loss: 0.836 - lr: 1.09e-05 - load time: 2.33 - gpu time: 24.98
# iter: 018000 - train loss: 0.840 - lr: 9.04e-06 - load time: 2.16 - gpu time: 23.37
# iter: 018200 - train loss: 0.838 - lr: 7.33e-06 - load time: 1.97 - gpu time: 24.31
# iter: 018400 - train loss: 0.839 - lr: 5.80e-06 - load time: 2.03 - gpu time: 24.38
# iter: 018600 - train loss: 0.836 - lr: 4.45e-06 - load time: 1.78 - gpu time: 23.74
# iter: 018800 - train loss: 0.837 - lr: 3.27e-06 - load time: 1.98 - gpu time: 23.86
# iter: 019000 - train loss: 0.839 - lr: 2.28e-06 - load time: 2.08 - gpu time: 25.72
# iter: 019200 - train loss: 0.837 - lr: 1.46e-06 - load time: 2.24 - gpu time: 23.76
# iter: 019400 - train loss: 0.839 - lr: 8.20e-07 - load time: 2.21 - gpu time: 23.64
# iter: 019600 - train loss: 0.837 - lr: 3.65e-07 - load time: 1.75 - gpu time: 23.73
# iter: 019800 - train loss: 0.837 - lr: 9.17e-08 - load time: 2.11 - gpu time: 23.62
# iter: 020000 - train loss: 0.838 - lr: 1.20e-09 - load time: 2.28 - gpu time: 24.66
# iter: 020000 - valid loss: 3.166 - acc full seq: 0.3001 - acc per char: 0.3524
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-1f14d1f7de28> in <cell line: 44>()
#      42
#      43 # huấn luyện xong thì lưu lại config để dùng cho Predictor
# ---> 44 trainer.config.save('config.yml')
#
# AttributeError: 'dict' object has no attribute 'save'
