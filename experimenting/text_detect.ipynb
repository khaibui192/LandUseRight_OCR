# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install roboflow
# !pip install ultralytics
# !pip install opencv-python
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 17.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.10.0.82
#     Uninstalling opencv-python-headless-4.10.0.82:
#       Successfully uninstalled opencv-python-headless-4.10.0.82
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 783.5/783.5 kB 10.5 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...

# %%
# from roboflow import Roboflow
# rf = Roboflow(api_key="GML2IhZDqdiQq6D2wOBw")
# project = rf.workspace("duythai").project("text_detection-gwcka")
# version = project.version(2)
# # dataset = version.download("yolov5")
# dataset = version.download("yolov8")

# %%
from ultralytics import YOLO
from ultralytics.data import YOLODataset

# %%
path = '/content/drive/MyDrive/OCR/Dataset/ocr.yaml'
model = YOLO('yolov8n.pt') # Load pretrain và finetune vài layer cuối. Transfer Learning
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 114MB/s]

# %%
results = model.train(data=path, epochs=300, imgsz=640)
# Out:
# Ultralytics YOLOv8.2.36 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=predict model="/content/drive/MyDrive/OCR/Weights/yolo/train/weights/best.pt" source="/content/drive/MyDrive/OCR/Test/8e39078f764dd5138c5c.jpg"
# Out:
# Ultralytics YOLOv8.2.36 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006428 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/drive/MyDrive/OCR/Test/8e39078f764dd5138c5c.jpg: 448x640 1 TD, 1 ST, 3 DCs, 1 B, 93.0ms
# Speed: 6.1ms preprocess, 93.0ms inference, 529.1ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
